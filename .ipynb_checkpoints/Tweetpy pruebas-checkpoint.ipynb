# %% [markdown]
# # ACTIVIDAD 2

# %% [markdown]
# ## GRUPO 2 - Carlos Gonzalez Van Liempt y Álvaro Farreny Boixader

# %% [markdown]
# <h2 style="font-size: 19px;color:#6DA0FF;font-family:Georgia, Times, 'Times New Roman', serif;letter-spacing: 3px;font-weight: normal">Twitter Web Scraping</h2>

# %%
pip install tweepy==4.12.0

# %%
"""pip install tweepy==3.10.0
pip install tweepy==4.12.0"""

# %%
try:
    import tweepy
except ModuleNotFoundError:
    # !pip install tweepy
    import tweepy
try: 
    import mysql.connector
except ModuleNotFoundError:
    # !pip install mysql-connector
    import mysql.connector

# %%
#con = mysql.connector.connect(user="root", password = "4995", host = "127.0.0.1", database="bdpythonia")
#cursor = con.cursor()
# cursor.execute("CREATE DATABASE bdpythonia")
#cursor.execute("USE bdpythonia;")
# Concatenar todos los tipos de datos
#cursor.execute("CREATE TABLE AnalisisSentimientosBTC (autor VARCHAR(255), tweetID VARCHAR(255), date VARCHAR(255), idioma VARCHAR(255), contenido TEXT);")

# %%
import pandas as pd
import time

df = pd.DataFrame(columns=['Autor', 'TweetID', 'Idioma', 'Contenido'])

client = tweepy.Client(bearer_token="AAAAAAAAAAAAAAAAAAAAAIV9iAEAAAAABkMM0c9J7Qe1jgFj%2BbtdW4C9vkw%3DSaUUIEGcbOwfPRgWoDKJ6BP6RAJ7wOzpT7SuEskgByo3EWLB3d") # Utilizamos el token Bearer para autentificarnos en twitter

#INFORMACIÓN SOBRE LOS VALORES QUE SE LE PUEDEN DAR A LA QUERY!!
# https://developer.twitter.com/en/docs/twitter-api/tweets/search/api-reference/get-tweets-search-all

query = "Bitcoin -is:retweet lang:en" # Introducimos con que mensajes queremos que filtre, junto con la condición de que no debe ser un retweet y el idioma debe ser en español
response = client.search_recent_tweets(query=query, max_results=50, tweet_fields=["lang","created_at"], expansions=["author_id"]) # realizamos la query con un límite de 20 tweets ( se puede modificar )

users = {u["id"]: u for u in response.includes["users"]} # Relacionamos el id de usuario con el nombre de usuario para crear una lista de usuarios con la que trabajar

for tweet in response.data:  
    if users[tweet.author_id]:
        user = users[tweet.author_id]
        df = df.append({'Autor':user.username,'TweetID':str(tweet.id),'Date':tweet.created_at,'Idioma':str(tweet.lang),'Contenido':str(tweet)},ignore_index=True) # Introducimos los valores en el dataframe
        ###cursor.execute("INSERT INTO AnalisisSentimientosBTC (autor, tweetID, date, idioma, contenido) VALUES ('"+str(user.username)+"',"+str(tweet.id)+",'"+str(tweet.created_at)+"','"+str(tweet.lang)+"','"+str(tweet)+"')")
        ###con.commit()
# Out:
# C:\Users\thena\AppData\Local\Temp\ipykernel_19340\3549100648.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Autor':user.username,'TweetID':str(tweet.id),'Date':tweet.created_at,'Idioma':str(tweet.lang),'Contenido':str(tweet)},ignore_index=True) # Introducimos los valores en el dataframe
# C:\Users\thena\AppData\Local\Temp\ipykernel_19340\3549100648.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Autor':user.username,'TweetID':str(tweet.id),'Date':tweet.created_at,'Idioma':str(tweet.lang),'Contenido':str(tweet)},ignore_index=True) # Introducimos los valores en el dataframe
# C:\Users\thena\AppData\Local\Temp\ipykernel_19340\3549100648.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Autor':user.username,'TweetID':str(tweet.id),'Date':tweet.created_at,'Idioma':str(tweet.lang),'Contenido':str(tweet)},ignore_index=True) # Introducimos los valores en el dataframe
# C:\Users\thena\AppData\Local\Temp\ipykernel_19340\3549100648.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Autor':user.username,'TweetID':str(tweet.id),'Date':tweet.created_at,'Idioma':str(tweet.lang),'Contenido':str(tweet)},ignore_index=True) # Introducimos los valores en el dataframe
# C:\Users\thena\AppData\Local\Temp\ipykernel_19340\3549100648.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Autor':user.username,'TweetID':str(tweet.id),'Date':tweet.created_at,'Idioma':str(tweet.lang),'Contenido':str(tweet)},ignore_index=True) # Introducimos los valores en el dataframe
# C:\Users\thena\AppData\Local\Temp\ipykernel_19340\3549100648.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Autor':user.username,'TweetID':str(tweet.id),'Date':tweet.created_at,'Idioma':str(tweet.lang),'Contenido':str(tweet)},ignore_index=True) # Introducimos los valores en el dataframe
# C:\Users\thena\AppData\Local\Temp\ipykernel_19340\3549100648.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Autor':user.username,'TweetID':str(tweet.id),'Date':tweet.created_at,'Idioma':str(tweet.lang),'Contenido':str(tweet)},ignore_index=True) # Introducimos los valores en el dataframe
# C:\Users\thena\AppData\Local\Temp\ipykernel_19340\3549100648.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Autor':user.username,'TweetID':str(tweet.id),'Date':tweet.created_at,'Idioma':str(tweet.lang),'Contenido':str(tweet)},ignore_index=True) # Introducimos los valores en el dataframe
# C:\Users\thena\AppData\Local\Temp\ipykernel_19340\3549100648.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Autor':user.username,'TweetID':str(tweet.id),'Date':tweet.created_at,'Idioma':str(tweet.lang),'Contenido':str(tweet)},ignore_index=True) # Introducimos los valores en el dataframe
# C:\Users\thena\AppData\Local\Temp\ipykernel_19340\3549100648.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Autor':user.username,'TweetID':str(tweet.id),'Date':tweet.created_at,'Idioma':str(tweet.lang),'Contenido':str(tweet)},ignore_index=True) # Introducimos los valores en el dataframe
# C:\Users\thena\AppData\Local\Temp\ipykernel_19340\3549100648.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Autor':user.username,'TweetID':str(tweet.id),'Date':tweet.created_at,'Idioma':str(tweet.lang),'Contenido':str(tweet)},ignore_index=True) # Introducimos los valores en el dataframe
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~\.conda\envs\IA\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     564                 query = query.encode("utf-8")
# --> 565             self._cmysql.query(
#     566                 query,
#
# MySQLInterfaceError: You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'checked' by the bitcoin network. lightning makes this all possible. https://t.co' at line 1
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19340\3549100648.py in <module>
#      18         user = users[tweet.author_id]
#      19         df = df.append({'Autor':user.username,'TweetID':str(tweet.id),'Date':tweet.created_at,'Idioma':str(tweet.lang),'Contenido':str(tweet)},ignore_index=True) # Introducimos los valores en el dataframe
# ---> 20         cursor.execute("INSERT INTO AnalisisSentimientosBTC (autor, tweetID, date, idioma, contenido) VALUES ('"+str(user.username)+"',"+str(tweet.id)+",'"+str(tweet.created_at)+"','"+str(tweet.lang)+"','"+str(tweet)+"')")
#      21         con.commit()
#
# ~\.conda\envs\IA\lib\site-packages\mysql\connector\cursor_cext.py in execute(self, operation, params, multi)
#     277
#     278         try:
# --> 279             result = self._cnx.cmd_query(
#     280                 stmt,
#     281                 raw=self._raw,
#
# ~\.conda\envs\IA\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     571             )
#     572         except MySQLInterfaceError as err:
# --> 573             raise get_mysql_exception(
#     574                 err.errno, msg=err.msg, sqlstate=err.sqlstate
#     575             ) from err
#
# ProgrammingError: 1064 (42000): You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'checked' by the bitcoin network. lightning makes this all possible. https://t.co' at line 1

# %%
df
# Out:
#               Autor              TweetID Idioma  \
# 0   sovereignmonkey  1597538183574482944     en
# 1   TonyRam08629749  1597538183490596864     en
# 2     RobertS136088  1597538182417063936     en
# 3     CryptoWizardd  1597538166642470913     en
# 4   CamachoClarissa  1597538163614167041     en
# 5      JackyDalshim  1597538157448552451     en
# 6     miningbraxton  1597538149923684352     en
# 7   KanishaMcdouga1  1597538143141785600     en
# 8        AppleMatej  1597538142554583041     en
# 9        changinl8r  1597538140721668096     en
# 10   0xEthereumYoda  1597538136737079296     en
# 11  ganeshs71340145  1597538136502198274     en
# 12        NewsVidia  1597538131909103616     en
# 13  JohnKel60734385  1597538130449793024     en
# 14  LivePriceCrypto  1597538124531367937     en
# 15   ArihoEdgarEdwa  1597538124242255875     en
# 16   richlamejunkie  1597538111353147392     en
# 17   Gold22_scarlet  1597538109612490753     en
# 18    hacwithbrian5  1597538105996636160     en
# 19  EricaHi36307711  1597538101882241024     en
# 20  KanishaMcdouga1  1597538101286821888     en
# 21   ChainplusFunds  1597538099223212033     en
# 22      SnorreLahti  1597538097276669952     en
# 23    smartcodeteh7  1597538094240395264     en
# 24   CIERRAHERRING5  1597538067119628289     en
# 25    hacwithbrian5  1597538064620212225     en
# 26   ArihoEdgarEdwa  1597538053127802880     en
# 27  KanishaMcdouga1  1597538050258923520     en
# 28  Thetech85672912  1597538044659531776     en
# 29  EveningStandard  1597538039596810241     en
# 30     standardnews  1597538038736879621     en
# 31    smartcodeteh7  1597538037969272832     en
# 32  shyllae68901911  1597538035595628546     en
# 33         aubre_y2  1597538033318137857     en
# 34  MetaPop84472651  1597538028154941440     en
# 35      CryptoTomBD  1597538026112032768     en
# 36   ArihoEdgarEdwa  1597538026057789440     en
# 37      ArcherWatt1  1597538019254435840     en
# 38  ZackWil10790721  1597538017644011520     en
# 39       ben_gravis  1597538016595410945     en
# 40    hacwithbrian5  1597538007464411138     en
# 41    HudsonEstell1  1597538005174059008     en
# 42    ThiagoSousafi  1597538003408125952     en
# 43   realBitcoinDog  1597538001285877760     en
# 44         aubre_y2  1597537997645557760     en
# 45   ArihoEdgarEdwa  1597537997368745985     en
# 46  KareenaSalley14  1597537994675998720     en
# 47    cliviagrahamE  1597537991555440640     en
# 48  KanishaMcdouga1  1597537988615229440     en
# 49   upavls48390028  1597537986237071362     en
#
#                                             Contenido  \
# 0   @RishiSunak @grantshapps @SteveBarclay @willqu...
# 1   @CryptoWizardd @OTC_Bitcoin I think this deser...
# 2   Dogecoin Takes A Jump Of 9.76%; Bitcoin, Ether...
# 3   That scammer still around scamming people. Wat...
# 4   Any phone will work as long as you haven't dow...
# 5   @julianhosp If you already have a lot of DFI, ...
# 6   @wokebutbroke23 I love @TaleOfSatoshi. I bough...
# 7   @DU09BTC #Bitcoin  prices might be volatile, b...
# 8                     what about Bitcoin @KRYPTOMates
# 9   @Pete_Down_Under @Bitcoin_King_ @withmalice @D...
# 10  #Ethereum price update: \n\n#ETH $1214.56 USD\...
# 11  @GeoffGr74476462 @MeTammySki @ArchieNeko_ @Arc...
# 12  ECB President reiterates calls for 'MiCA II' i...
# 13  @Davincij15 You dont need a house, you need bi...
# 14  #Bitcoin Last Price $16495 #BTC 🚀\nWeekly Indi...
# 15  @justinenantale2 Being the head of the home is...
# 16               @CarlBMenger running bitcoin as well
# 17  $AUTO BEST GEM ON THIS MARKET! PUMP IT UPP #Bi...
# 18  Your Condition is not even as critical as thos...
# 19  Why bitcoin is worse than a Madoff-style Ponzi...
# 20  @rovercrc #Bitcoin  prices might be volatile, ...
# 21  $FTM Left (FTM/BTC) : #Fantom is a good coin t...
# 22  This zesty faucet from @_bitcoiner is making m...
# 23  Your Condition is not even as critical as thos...
# 24  Who doesn't have Temu app and wants $20?\n$20 ...
# 25  Your Condition is not even as critical as thos...
# 26  @Rachealkyy Being the head of the home isn't e...
# 27  @MichaelRoerade #Bitcoin  prices might be vola...
# 28  @Valenti44537545 @coin_gabbar @Bitcoin @ethere...
# 29  Digital exchange Bitfront closes for business ...
# 30  Digital exchange Bitfront closes for business ...
# 31  Your Condition is not even as critical as thos...
# 32  @Virtual85423747 @coin_gabbar @Bitcoin @ethere...
# 33  @CryptoMichNL Don’t get to optimistic from thi...
# 34  @SteveBr22049789 @coin_gabbar @Bitcoin @ethere...
# 35  Spanish Securities Regulator CNMV Warns About ...
# 36  @Rachealkyy Being the head of the home isn't e...
# 37                             #Bitcoin correction! 👀
# 38  @EliteBb10599233 @coin_gabbar @Bitcoin @ethere...
