# %% [markdown]
# # ACTIVIDAD 2

# %% [markdown]
# ## GRUPO 2 - Carlos Gonzalez Van Liempt y Álvaro Farreny Boixader

# %% [markdown]
# <h2 style="font-size: 19px;color:#6DA0FF;font-family:Georgia, Times, 'Times New Roman', serif;letter-spacing: 3px;font-weight: normal">Twitter Web Scraping</h2>

# %%
pip install tweepy==4.12.0
# Out:
# Requirement already satisfied: tweepy==4.12.0 in c:\users\farre\anaconda3\lib\site-packages (4.12.0)
# Requirement already satisfied: requests-oauthlib<2,>=1.2.0 in c:\users\farre\anaconda3\lib\site-packages (from tweepy==4.12.0) (1.3.1)
# Requirement already satisfied: requests<3,>=2.27.0 in c:\users\farre\anaconda3\lib\site-packages (from tweepy==4.12.0) (2.28.1)
# Requirement already satisfied: oauthlib<4,>=3.2.0 in c:\users\farre\anaconda3\lib\site-packages (from tweepy==4.12.0) (3.2.2)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\farre\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy==4.12.0) (2.0.8)
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: certifi>=2017.4.17 in c:\users\farre\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy==4.12.0) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\farre\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy==4.12.0) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\farre\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy==4.12.0) (1.26.4)

# %%
"""pip install tweepy==3.10.0
pip install tweepy==4.12.0"""
# Out:
# 'pip install tweepy==3.10.0\npip install tweepy==4.12.0'

# %%
try:
    import tweepy
except ModuleNotFoundError:
    # !pip install tweepy

# %%
import pandas as pd
import time

df = pd.DataFrame(columns=['Autor', 'TweetID', 'Idioma', 'Contenido'])

client = tweepy.Client(bearer_token="AAAAAAAAAAAAAAAAAAAAAIV9iAEAAAAABkMM0c9J7Qe1jgFj%2BbtdW4C9vkw%3DSaUUIEGcbOwfPRgWoDKJ6BP6RAJ7wOzpT7SuEskgByo3EWLB3d") # Utilizamos el token Bearer para autentificarnos en twitter

#INFORMACIÓN SOBRE LOS VALORES QUE SE LE PUEDEN DAR A LA QUERY!!
# https://developer.twitter.com/en/docs/twitter-api/tweets/search/api-reference/get-tweets-search-all

query = "Bitcoin -is:retweet lang:es" # Introducimos con que mensajes queremos que filtre, junto con la condición de que no debe ser un retweet y el idioma debe ser en español
response = client.search_recent_tweets(query=query, max_results=50, tweet_fields=["lang"], expansions=["author_id"]) # realizamos la query con un límite de 20 tweets ( se puede modificar )

users = {u["id"]: u for u in response.includes["users"]} # Relacionamos el id de usuario con el nombre de usuario para crear una lista de usuarios con la que trabajar

for tweet in response.data:  
    if users[tweet.author_id]:
        user = users[tweet.author_id]
        df = df.append({'Autor':user.username,'TweetID':str(tweet.id),'Idioma':str(tweet.lang),'Contenido':str(tweet)},ignore_index=True) # Introducimos los valores en el dataframe

# %%
df
# Out:
#               Autor              TweetID Idioma  \
# 0   Bloisilenselegn  1595720945758769155     es
# 1   LaCriptomoneda1  1595720945163210755     es
# 2   rolando83943562  1595720619135475712     es
# 3         cephaloon  1595720184656003074     es
# 4      BullTrainers  1595720177014181888     es
# 5    FoundedSatoshi  1595720170064187393     es
# 6     HastaCuandoSV  1595719955173052417     es
# 7        hold_trade  1595719755822174208     es
# 8           eamplus  1595719629606993921     es
# 9    LunaValienteRD  1595719467086012416     es
# 10     CryptoJoseJM  1595719405413228545     es
# 11      EpicGemx100  1595719288492642307     es
# 12         Corbhata  1595719217407733760     es
# 13  tallerdeinvers1  1595719121835991040     es
# 14     CriptoPasion  1595719080811454465     es
# 15    cripto_diario  1595719058707578883     es
# 16       LeeElinor6  1595718925320613891     es
# 17     CriptosEnEsp  1595718922296139777     es
# 18      TCE_Capital  1595718895301705728     es
# 19         _Mareek_  1595718894903332864     es
# 20   Cryptomonkey01  1595718891489361922     es
# 21     orbitaldonut  1595718885231284224     es
# 22         bitapeso  1595718880286347264     es
# 23    ChinetCapital  1595718869628293121     es
# 24        Brunvelop  1595718814276399104     es
# 25   CARBABOGLEHEAD  1595718723247411201     es
# 26        achuguayo  1595718564769681408     es
# 27         awayitor  1595718438319702021     es
# 28        debateive  1595718235243962368     es
# 29       NarancoMr1  1595718136673832960     es
# 30      chema_ramos  1595718023142596608     es
# 31         leroytxo  1595717914937774082     es
# 32        Sebas_Orc  1595717817432965123     es
# 33     XabierLazaro  1595717806254788608     es
# 34  DaniensDaniens5  1595717528357044225     es
# 35         UnderOil  1595717396375175169     es
# 36  LaCriptomoneda1  1595717246244225028     es
# 37      EducaCripto  1595717158495027201     es
# 38          Vaundie  1595716757565612033     es
# 39     CriptosisCom  1595716679165612032     es
# 40           By9cX7  1595716059310559232     es
# 41     FaraonCripto  1595716032186159104     es
# 42    thomasduke662  1595715771568689154     es
# 43    thomasduke662  1595715726916059136     es
# 44         VHaenelt  1595715641268473857     es
# 45         chiton98  1595715491288555521     es
# 46    EstrategiasTv  1595715157908492289     es
# 47  healthy_pockets  1595715063557521410     es
# 48   Jess_toptrader  1595714817335115777     es
# 49      guachipIay_  1595714748208881665     es
#
#                                             Contenido
# 0    https://t.co/VKqBXzEDBR\n\nBITCOIN: ¡¡¡¡SÍÍÍ‼️‼️
# 1   El mezclador de Bitcoin es acusado de ser una ...
# 2   @MigueVaquerano @nayibbukele Q DEVUELVA ESTE L...
# 3   #Bitcoin lleva un año en canal bajista. Desde ...
# 4   Micro Noticias y Novedades #Criptomonedas #Bit...
# 5   @Sebas_Orc Realmente aunque todo este en unas ...
# 6   MÁS DE 50 MILLONES DE DÓLARES EN BITCOIN SE ES...
# 7   @Techconcatalina "LEY de Emisión de Activos Di...
# 8   @lunaticoin Escuché por primera vez sobre Bitc...
# 9   Nueva York toma la iniciativa en regular las c...
# 10  Monedero Bitcoin vinculado al hack de Mt. Gox ...
# 11  Digital Securities Bill Paves Way for Bitcoin ...
# 12  Gana dólares y criptos registrándote en Uphold...
# 13  No solo los #exchanges han salido mal parados ...
# 14  CryptoSlate Wrapped Daily: puntos de la cinta ...
# 15  "Sam Bankman-Fried sigue hablando en eventos y...
# 16          Compra #bitcoin, igual no te van a querer
# 17  #CryptoTopCuatro\n📣 Aquí tenéis el top cuatro ...
# 18  @eco_liberal Hay que tener en cuenta, mas impo...
# 19  @ManiThawani Bastante temprano he leído hoy la...
# 20  El precio del Bitcoin al momento ---&gt;$320,4...
# 21  24-11-2022 - UTC 10:00:00 - Actualización de B...
# 22  Precio actual del #Bitcoin, #Ethereum y #Rippl...
# 23  El Salvador presentó proyecto de ley que invol...
# 24  Comparación de la adopción de Stable Diffussio...
# 25  @carlaconwifi Sería necesario un nivel cero pa...
# 26  @Guille21MB @jess_btc Pues mis euros se han ap...
# 27  El próximo rechazo de #bitcoin se encuentra en...
# 28  VICMOVEOfficial Go go goooo#Vim #vicmove #Btc ...
# 29  @CasabanRoberto Solo hay que separar el dinero...
# 30  ¿Qué respalda a #Bitcoin?🤔\n\nSi entendemos qu...
# 31  @ivan_unalcoyano @RedondoMarcos @TheBloodySton...
# 32  No sé si alguna vez llegué a creer en la desce...
# 33  ¡Una mas sobre marketing y publicidad ! https:...
# 34  @andyromerodev @ErichGarciaCruz @nayibbukele E...
# 35  Os dejamos todas las ventajas del BLACK FRIDAY...
# 36  La nueva ley fiscal de Bitcoin https://t.co/lg...
# 37  Monedero Bitcoin vinculado al hack de Mt. Gox ...
# 38  El Salvador introduces bill for bitcoin bonds ...
# 39  El ethereum no puede con los 1.800 y se comple...
# 40  Amenazará la existencia de Bitcoin en un futur...
# 41  Primero llegó Internet. Luego la web 2.0. Lueg...
# 42  @guardiacivil @osiseguridad Bienvenido a 💪👏\n ...
# 43  Bienvenido a 💪👏\n         📃 🇪🇸TECHOVER MUNDO D...
# 44  @ManiThawani Mani, lo mismo te hace un bocata ...
# 45  @PujaEspe dejo de tener dinero para poder hace...
# 46  🪙¿Vuelta del #Bitcoin a los 20.000 dólares? Es...
# 47  💥DATO CURIOSO: El gigante financiero Fidelity ...
# 48  Ppales. inversores en #BTC :\n\n1.Greyscale ($...
# 49  @jess_btc Haces igual que yo. Compro cada sema...
