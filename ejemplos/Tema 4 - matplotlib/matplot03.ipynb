# %%
# Construcción de histogramas.

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv("../../data/Cap 8/base_datos_2008.csv")

# %%
# Eliminamos los datos que faltan de nuestra BD, y un subconjunto de las variables que nos interesa estudiar.
# Con inplace = True indicamos que no necesitamos devolver el resultado en otra variable.

df.dropna(inplace = True, subset = ["ArrDelay", "DepDelay", "Distance"])

sns.distplot(df["Distance"])
# Out:
# C:\Users\feeadmin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Distance', ylabel='Density'>

# %%
# Con kde = False suprimo la aproximación a curva que hace el sistema

sns.distplot(df["Distance"], kde = False)
# Out:
# C:\Users\feeadmin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Distance'>

# %%
# En este caso puedo ajustar el número de bins que tiene nuestro histograma
sns.distplot(df["Distance"], kde = False, bins = 100)
# Out:
# <AxesSubplot:xlabel='Distance'>

# %%
# Para comparar dos distribuciones

sns.kdeplot(df["ArrDelay"])
sns.kdeplot(df["DepDelay"])

# Acotamos los ejes ya que hay bastantes outliers
plt.xlim ([-300, 300])
# Out:
# (-300.0, 300.0)

# %%
# Diagramas más básicos, indicando los vuelos que hayan salido de los distintos puntos.
# Vamos a coger solo 500 datos.

df2 = df[df["Origin"].isin(["ATL", "HOU", "IND"])].sample(frac = 1).head(500)

# %%
# Visualizamos el Origen en el eje Y y el Retardo de salida en el Eje X

sns.boxplot(x="DepDelay", y = "Origin", data = df2)
# Out:
# <AxesSubplot:xlabel='DepDelay', ylabel='Origin'>

# %%
sns.boxplot(x="DepDelay", y = "Origin", data = df2)
# Si queremos ajustar las cajas, podemos hacer
plt.xlim ([-20, 150])
# Out:
# (-20.0, 150.0)

# %% [markdown]
# La línea que separa las cajas corresponde con la mediana, divide el 50% de los casos del otro 50%. El límite inferior de la caja corresponde al primer cuartil, el tercer cuartil corresponde con el límite superior de la caja. El resto son outliers.
